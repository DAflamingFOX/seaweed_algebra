# %% [markdown]
# # Basic Seaweed Algebra Jupyter Notebook Demo

# %% [markdown]
# The following block runs a script to install the seaweed-algebra (and its dependent) package(s) from pip, see the [README](https://github.com/DAflamingFOX/seaweed_algebra/blob/main/README.md) for more info on how this works.

# %%
# !pip install seaweed-algebra
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaweed-algebra in /home/jeff/.local/lib/python3.14/site-packages (0.0.5.dev13+g67589b3d6)
# Requirement already satisfied: matplotlib>=3.10.0 in /home/jeff/.local/lib/python3.14/site-packages (from seaweed-algebra) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jeff/.local/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jeff/.local/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jeff/.local/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jeff/.local/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/jeff/.local/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/jeff/.local/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.14/site-packages (from matplotlib>=3.10.0->seaweed-algebra) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.0->seaweed-algebra) (1.17.0)

# %% [markdown]
# Now that we've installed the library, we can actually use it.
#
# Below is a very basic python script to show the library is functioning as expected.

# %%
from seaweed_algebra import Meander, Seaweed
from seaweed_algebra.visual import plot_meander, plot_seaweed

from matplotlib import pyplot as plt

sw = Seaweed([17, 3], [10, 4, 6])
m = Meander.from_seaweed(sw)

plot_seaweed(sw)
plot_meander(m)

plt.show()
